# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv(r'C:\Users\Chief Adewusi\Downloads\Datascience\StudentsPerformance.csv')

# %% [markdown]
# # Summary Function

# %%
#getting data for the top column
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#getting data for the bottom column
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#gives the top fifteen data
data.head(15)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
#gives the 20 bottom data
data.tail(20)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 980  female        group B                 high school  free/reduced
# 981    male        group D            some high school      standard
# 982    male        group B            some high school      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 985    male        group A                 high school      standard
# 986  female        group C          associate's degree      standard
# 987    male        group E            some high school      standard
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# ...

# %%
#shows the number of rows and columns
data.shape
# Out:
# (1000, 8)

# %%
data.info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#data in the columns
print(data.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# # data for gender

# %%
#dataframe- collecting only data for gender
data[['gender']]
# Out:
#      gender
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# ..      ...
# 995  female
# 996    male
# 997  female
# 998  female
# 999  female
#
# [1000 rows x 1 columns]

# %%
#series-collecting only data for gender
data['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
data['gender'].dtype
#object type
# Out:
# dtype('O')

# %%
data['gender'].values
# Out:
# array(['female', 'female', 'female', 'male', 'male', 'female', 'female',
#        'male', 'male', 'female', 'male', 'male', 'female', 'male',
#        'female', 'female', 'male', 'female', 'male', 'female', 'male',
#        'female', 'male', 'female', 'male', 'male', 'male', 'female',
#        'male', 'female', 'female', 'female', 'female', 'male', 'male',
#        'male', 'female', 'female', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'male', 'female', 'female', 'female',
#        'male', 'male', 'male', 'male', 'male', 'female', 'female',
#        'female', 'male', 'male', 'female', 'male', 'male', 'male',
#        'female', 'female', 'male', 'male', 'female', 'male', 'female',
#        'female', 'male', 'female', 'male', 'male', 'male', 'male', 'male',
#        'female', 'female', 'female', 'male', 'male', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'female', 'male',
# ...

# %%
#determine the number of females and males
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
print(data['gender'].unique())
# Out:
# ['female' 'male']

# %%
data.groupby(['gender']).mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
data.groupby(['gender']).max()
# Out:
#        race/ethnicity parental level of education     lunch  \
# gender
# female        group E            some high school  standard
# male          group E            some high school  standard
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none         100            100            100
# male                      none         100            100            100

# %%
data.groupby(['gender']).min()
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group A          associate's degree  free/reduced
# male          group A          associate's degree  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female               completed           0             17             10
# male                 completed          27             23             15

# %%
#only counts the reading score for each gender
data.groupby('gender')[['reading score']].count()
# Out:
#         reading score
# gender
# female            518
# male              482

# %%
#only shows the mean scores for genders
data.groupby(['gender', 'math score']).mean()
# Out:
#                    reading score  writing score
# gender math score
# female 0                   17.00          10.00
#        8                   24.00          23.00
#        18                  32.00          28.00
#        19                  38.00          32.00
#        22                  39.00          33.00
# ...                          ...            ...
# male   96                  90.00          92.00
#        97                  88.50          86.75
#        98                  86.50          90.00
#        99                  87.00          81.00
#        100                 98.25          94.50
#
# [147 rows x 2 columns]

# %%
#only shows the mean math scores
data.groupby('gender')[['math score']].mean()
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %%
data.groupby(['gender'], sort=False)[['math score']].mean()
# Out:
#         math score
# gender
# female   63.633205
# male     68.728216

# %% [markdown]
# # data summary function

# %%
data[['race/ethnicity']]
# Out:
#     race/ethnicity
# 0          group B
# 1          group C
# 2          group B
# 3          group A
# 4          group C
# ..             ...
# 995        group E
# 996        group C
# 997        group C
# 998        group D
# 999        group D
#
# [1000 rows x 1 columns]

# %%
data[['race/ethnicity']].value_counts()
# Out:
# race/ethnicity
# group C           319
# group D           262
# group B           190
# group E           140
# group A            89
# dtype: int64

# %%
data['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %% [markdown]
# # Grouping

# %%
data.groupby('race/ethnicity')[['writing score']].count()
# Out:
#                 writing score
# race/ethnicity
# group A                    89
# group B                   190
# group C                   319
# group D                   262
# group E                   140

# %%
data.groupby('race/ethnicity')[['writing score']].std()
# Out:
#                 writing score
# race/ethnicity
# group A             15.468278
# group B             15.625173
# group C             14.983378
# group D             14.367707
# group E             15.113906

# %%
data[['parental level of education']]
# Out:
#     parental level of education
# 0             bachelor's degree
# 1                  some college
# 2               master's degree
# 3            associate's degree
# 4                  some college
# ..                          ...
# 995             master's degree
# 996                 high school
# 997                 high school
# 998                some college
# 999                some college
#
# [1000 rows x 1 columns]

# %%
data.groupby('parental level of education')[['gender']].max()
# Out:
#                             gender
# parental level of education
# associate's degree            male
# bachelor's degree             male
# high school                   male
# master's degree               male
# some college                  male
# some high school              male

# %%
data.groupby('parental level of education')[['gender']].count()
# Out:
#                              gender
# parental level of education
# associate's degree              222
# bachelor's degree               118
# high school                     196
# master's degree                  59
# some college                    226
# some high school                179

# %%
data['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
data['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
data['math score'].value_counts()
# Out:
# 65    36
# 62    35
# 69    32
# 59    32
# 61    27
#       ..
# 24     1
# 26     1
# 28     1
# 33     1
# 0      1
# Name: math score, Length: 81, dtype: int64

# %%
data['writing score'].value_counts()
# Out:
# 74    35
# 70    33
# 68    31
# 73    28
# 80    27
#       ..
# 23     1
# 28     1
# 35     1
# 15     1
# 10     1
# Name: writing score, Length: 77, dtype: int64

# %%
data['reading score'].std()
# Out:
# 14.60019193725222

# %%
data['writing score'].mean()
# Out:
# 68.054

# %% [markdown]
# # Filtering data

# %%
import numpy as np

# %%
#calculate mean math score
data['math score']>75
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: math score, Length: 1000, dtype: bool

# %%
##data for math score greater than 75
data[data['math score']>75]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 13     male        group A                some college      standard
# 16     male        group C                 high school      standard
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#data for reading score greater than 90
data[data['reading score']>90]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 2    female        group B             master's degree  standard
# 6    female        group B                some college  standard
# 102  female        group D          associate's degree  standard
# 106  female        group D             master's degree  standard
# 114  female        group E           bachelor's degree  standard
# ..      ...            ...                         ...       ...
# 957  female        group D             master's degree  standard
# 962  female        group E          associate's degree  standard
# 970  female        group D           bachelor's degree  standard
# 979  female        group C          associate's degree  standard
# 995  female        group E             master's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 2                      none          90             95             93
# ...

# %%
#data for the first 300 people who has a reading score greater than 90
data.head(300)[data.head(300)['reading score']>90]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 102  female        group D          associate's degree      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 120  female        group C           bachelor's degree      standard
# 122  female        group C                some college      standard
# 125  female        group B                 high school      standard
# 149    male        group E          associate's degree  free/reduced
# 164  female        group E             master's degree      standard
# 165  female        group C           bachelor's degree      standard
# 175  female        group C             master's degree      standard
# 179  female        group D            some high school      standard
# ...

# %%
data_90 = data.head(300)[data.head(300)['reading score']>90]

# %%
print(data_90)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 102  female        group D          associate's degree      standard
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 120  female        group C           bachelor's degree      standard
# 122  female        group C                some college      standard
# 125  female        group B                 high school      standard
# 149    male        group E          associate's degree  free/reduced
# 164  female        group E             master's degree      standard
# 165  female        group C           bachelor's degree      standard
# 175  female        group C             master's degree      standard
# 179  female        group D            some high school      standard
# ...

# %%
#data for females only
data[data['gender'] == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data[data['parental level of education'] == 'high school']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 12   female        group B                 high school      standard
# 16     male        group C                 high school      standard
# 20     male        group D                 high school      standard
# ..      ...            ...                         ...           ...
# 985    male        group A                 high school      standard
# 990    male        group E                 high school  free/reduced
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.groupby('parental level of education')[['gender' , 'lunch']].max()
# Out:
#                             gender     lunch
# parental level of education
# associate's degree            male  standard
# bachelor's degree             male  standard
# high school                   male  standard
# master's degree               male  standard
# some college                  male  standard
# some high school              male  standard

# %%
data.groupby('parental level of education')[['math score' , 'reading score']].mean()
# Out:
#                              math score  reading score
# parental level of education
# associate's degree            67.882883      70.927928
# bachelor's degree             69.389831      73.000000
# high school                   62.137755      64.704082
# master's degree               69.745763      75.372881
# some college                  67.128319      69.460177
# some high school              63.497207      66.938547

# %% [markdown]
# # Slicing

# %%
#collects data for index 0
data.loc[0]
# Out:
# gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object

# %%
#slicing a row
#collecta data for fourth row(3)
data.iloc[3]
# Out:
# gender                                       male
# race/ethnicity                            group A
# parental level of education    associate's degree
# lunch                                free/reduced
# test preparation course                      none
# math score                                     47
# reading score                                  57
# writing score                                  44
# Name: 3, dtype: object

# %%
#slicing a column
#collecting data for second column(1)
data.iloc[:,1]
# Out:
# 0      group B
# 1      group C
# 2      group B
# 3      group A
# 4      group C
#         ...
# 995    group E
# 996    group C
# 997    group C
# 998    group D
# 999    group D
# Name: race/ethnicity, Length: 1000, dtype: object

# %%
#selecting test preparation course from first and second row
data.iloc[1:3, 4]
# Out:
# 1    completed
# 2         none
# Name: test preparation course, dtype: object

# %%
data.iloc[[10, 11, 13], 2]
# Out:
# 10    associate's degree
# 11    associate's degree
# 13          some college
# Name: parental level of education, dtype: object

# %%
#obataining the 590th entry in writing score
data.loc[590, 'writing score']
# Out:
# 54

# %%
data.loc[:, ['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
data.loc[[0, 10, 100], ['gender', 'math score', 'lunch']]
# Out:
#      gender  math score     lunch
# 0    female          72  standard
# 10     male          58  standard
# 100    male          79  standard

# %% [markdown]
# # Conditional selection

# %%
#identify only females 
data.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
#to identify only female data
data.loc[data.gender == 'female'] #only 518 persons are female
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#isin allows the selection of data whose value 'is in' a list of values
data.loc[data['parental level of education'].isin(['high school', 'some college'])] #gives data for high school and some college
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 994    male        group A                 high school      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.loc[data['test preparation course'].notnull()]#checks for empty data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True            True                         True   True
# 3      True            True                         True   True
# 4      True            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
data[data.isnull()]
# Out:
#     gender race/ethnicity parental level of education lunch  \
# 0      NaN            NaN                         NaN   NaN
# 1      NaN            NaN                         NaN   NaN
# 2      NaN            NaN                         NaN   NaN
# 3      NaN            NaN                         NaN   NaN
# 4      NaN            NaN                         NaN   NaN
# ..     ...            ...                         ...   ...
# 995    NaN            NaN                         NaN   NaN
# 996    NaN            NaN                         NaN   NaN
# 997    NaN            NaN                         NaN   NaN
# 998    NaN            NaN                         NaN   NaN
# 999    NaN            NaN                         NaN   NaN
#
#     test preparation course  math score  reading score  writing score
# 0                       NaN         NaN            NaN            NaN
# 1                       NaN         NaN            NaN            NaN
# ...

# %% [markdown]
# # Dtype(Data type)

# %%
data['math score'].dtype
# Out:
# dtype('int64')

# %%
data['gender'].dtype
#object data type
# Out:
# dtype('O')

# %%
data.dtypes #gives all data types
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#converting int64 to float64
data['math score'].astype('float64')
# Out:
# 0      72.0
# 1      69.0
# 2      90.0
# 3      47.0
# 4      76.0
#        ...
# 995    88.0
# 996    62.0
# 997    59.0
# 998    68.0
# 999    77.0
# Name: math score, Length: 1000, dtype: float64

# %% [markdown]
# # Missing data

# %%
#pd.isnull is used to check for missing data
data[pd.isnull(data.gender)]#check if there are missing data
#no missing data
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
#replace is used to replace words
data.lunch.replace("standard", "modern") #replace standard in lunch to modern
# Out:
# 0            modern
# 1            modern
# 2            modern
# 3      free/reduced
# 4            modern
#            ...
# 995          modern
# 996    free/reduced
# 997    free/reduced
# 998          modern
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %% [markdown]
# # Sorting

# %%
data.sort_values(by='lunch')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group D                some college  free/reduced
# 363  female        group D            some high school  free/reduced
# 757    male        group E           bachelor's degree  free/reduced
# 758  female        group D                some college  free/reduced
# 760  female        group C                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 404  female        group C                 high school      standard
# 405  female        group C            some high school      standard
# 406    male        group B          associate's degree      standard
# 409    male        group D          associate's degree      standard
# 499    male        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.sort_values(by='reading score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 327    male        group A                some college  free/reduced
# 596    male        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 76     male        group E            some high school      standard
# ..      ...            ...                         ...           ...
# 106  female        group D             master's degree      standard
# 594  female        group C           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data['parental level of education'].sort_values()
# Out:
# 669    associate's degree
# 457    associate's degree
# 454    associate's degree
# 452    associate's degree
# 173    associate's degree
#               ...
# 513      some high school
# 515      some high school
# 265      some high school
# 853      some high school
# 336      some high school
# Name: parental level of education, Length: 1000, dtype: object

# %%
data.sort_values(by=['lunch', 'math score', 'reading score', 'test preparation course'], ascending=(True, True, True, False))
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 145  female        group C                some college  free/reduced
# 842  female        group B                 high school  free/reduced
# ..      ...            ...                         ...           ...
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 916    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data['math score'].sort_index()
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
data.sort_values(by='parental level of education', ascending=True)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 669    male        group D          associate's degree      standard
# 457    male        group D          associate's degree  free/reduced
# 454  female        group C          associate's degree  free/reduced
# 452  female        group C          associate's degree  free/reduced
# 173  female        group C          associate's degree      standard
# ..      ...            ...                         ...           ...
# 513  female        group B            some high school      standard
# 515  female        group C            some high school      standard
# 265    male        group D            some high school  free/reduced
# 853    male        group E            some high school      standard
# 336    male        group D            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...
